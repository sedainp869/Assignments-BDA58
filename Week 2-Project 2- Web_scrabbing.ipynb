# %% [markdown]
# ## IMDb Movie Reviews: Scraping & Cleaning the movie ratings

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
 
url = 'https://www.kaggle.com/datasets/rajugc/imdb-top-250-movies-dataset'
 
response = requests.get(url, headers=headers)
 
soup = BeautifulSoup(response.content, 'html.parser')
 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    IMDB Top 250 Movies Dataset | Kaggle
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="The Most Highly Rated Movies on IMDB: A Scraped Dataset of the Top 250" name="description"/>
#   <meta content="movies and tv shows,data visualization,exploratory data analysis,python" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="#008ABC" name="theme-color">
#    <script nonce="bGKb6HYkLBlgW6IvqRBx3A==" type="text/javascript">
#     window["pageRequestStartTime"] = 1727561705019;
#     window["pageRequestEndTime"] = 1727561705124;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#    </script>
#    <script async="" defer="" id="gsi-client" nonce="bGKb6HYkLBlgW6IvqRBx3A==" src="https://accounts.google.com/gsi/client">
#    </script>
# ...

# %%
soup.title
# Out:
# <title>IMDB Top 250 Movies Dataset | Kaggle</title>

# %%
soup.body
# Out:
# <body>
# <main>
# <div id="site-container"></div>
# <div class="hide" id="site-body">
# <script nonce="Ru2TKid1Y4bS60jMRtQqTQ==" type="text/x-mathjax-config">
#     MathJax.Hub.Config({
#     "HTML-CSS": {
#     preferredFont: "TeX",
#     availableFonts: ["STIX", "TeX"],
#     linebreaks: {
#     automatic: true
#     },
#     EqnChunk: (MathJax.Hub.Browser.isMobile ? 10 : 50)
#     },
#     tex2jax: {
#     inlineMath: [["\\(", "\\)"], ["\\\\(", "\\\\)"]],
#     displayMath: [["$$", "$$"], ["\\[", "\\]"]],
#     processEscapes: true,
#     ignoreClass: "tex2jax_ignore|dno"
#     },
#     TeX: {
#     noUndefined: {
#     attributes: {
#     mathcolor: "red",
#     mathbackground: "#FFEEEE",
#     mathsize: "90%"
#     }
#     }
#     },
#     Macros: {
#     href: "{}"
#     },
#     skipStartupTypeset: true,
#     messageStyle: "none",
#     extensions: ["Safe.js"],
#     });
# </script>
# <script nonce="Ru2TKid1Y4bS60jMRtQqTQ==" type="text/javascript">
# ...

# %%
soup.a

# %%
entire = soup.find_all('a')
entire
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>IMDB Top 250 Movies Dataset | Kaggle</title>
# <meta charset="utf-8"/>
# <meta content="index, follow" name="robots"/>
# <meta content="The Most Highly Rated Movies on IMDB: A Scraped Dataset of the Top 250" name="description"/>
# <meta content="movies and tv shows,data visualization,exploratory data analysis,python" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
# <meta content="#008ABC" name="theme-color">
# <script nonce="Ru2TKid1Y4bS60jMRtQqTQ==" type="text/javascript">
#     window["pageRequestStartTime"] = 1727544966402;
#     window["pageRequestEndTime"] = 1727544966469;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
# <script async="" defer="" id="gsi-client" nonce="Ru2TKid1Y4bS60jMRtQqTQ==" src="https://accounts.google.com/gsi/client"></script>
# ...

# %%
# Convert to DataFrame
df = pd.DataFrame(movie_list, columns=['Rank', 'Title', 'Year', 'Rating'])
df
# Out:
# Empty DataFrame
# Columns: [Rank, Title, Year, Rating]
# Index: []

# %%
# Display the first few rows of the dataset
print(df.head())
# Out:
# Empty DataFrame
# Columns: [Rank, Title, Year, Rating]
# Index: []

# %%
# Check the number of movies in the dataset
print(f"Number of movies scraped: {len(df)}")

# Ensure there are at least 100 movies
sample_df = df.head(100)  # Extract a sample of 100 movies

# Save the sample dataset to CSV
sample_df.to_csv('imdb_top_100_sample.csv', index=False)
print("Sample of 100 movies saved.")
# Out:
# Number of movies scraped: 0
# Sample of 100 movies saved.

# %%
# Check for missing values in the dataset
print(df.isnull().sum())

# Handle any missing values (if applicable) - in this case, there should be none
df.dropna(inplace=True)

# Check for duplicate entries
df.drop_duplicates(inplace=True)

# Check data types of the columns
print(df.dtypes)
# Out:
# Rank      0
# Title     0
# Year      0
# Rating    0
# dtype: int64
# Rank      object
# Title     object
# Year      object
# Rating    object
# dtype: object
